# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Math-Stuff-For-Tests/blob/main/ANotebookFullOfMaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **A Notebook Full Of Maths!**
#
# This is a notebook containing markdowns, math notes, and equations for math on the SAT that I hope will help.

# %% [markdown]
# ### SAT Math Curriculum
#
# #### Phase 0 — Mathematical Fluency
# - Fractions, decimals, and percentages
# - Ratios and proportions
# - Negative numbers and order of operations
# - Exponents and roots
# - Algebraic notation
# - Distributive property
# - Combining like terms
# - Factoring basics
# - Rearranging equations
# - Units and unit conversions
#
# #### Phase 1 — Linear Algebra
# - Linear equations
#   - One-step and multi-step equations
#   - Variables on both sides
#   - Fractions in equations
#   - Literal equations
#   - Equations with parameters
#   - Translating words into equations
# - Linear functions
#   - Slope
#   - Intercept
#   - Rate of change
#   - Tables
#   - Graphs
#   - Equations
#   - Function notation
#   - Equation, graph, and table relationships
# - Systems of equations
#   - Substitution
#   - Elimination
#   - Graphical interpretation
#   - Number of solutions
#   - No solution
#   - Infinitely many solutions
#   - Systems in word problems
# - Linear inequalities
#   - Solving inequalities
#   - Graphing inequalities
#   - Compound inequalities
#   - Systems of inequalities
# - Cumulative linear algebra practice
#
# #### Phase 2 — Nonlinear Algebra
# - Exponents
#   - Exponent rules
#   - Negative exponents
#   - Fractional exponents
#   - Scientific notation
# - Exponential relationships
#   - Exponential growth
#   - Exponential decay
#   - Percent growth
#   - Linear vs. exponential change
#   - Exponential equations
#   - Interpreting parameters
# - Quadratics
#   - Factoring
#   - Standard form
#   - Vertex form
#   - Factored form
#   - Zeros
#   - Vertex
#   - Axis of symmetry
#   - Graph interpretation
#   - Completing the square
#   - Quadratic formula
#   - Discriminant
# - Polynomials
#   - Polynomial operations
#   - Factoring
#   - Zeros
#   - Polynomial graphs
#   - Equivalent expressions
# - Rational expressions
#   - Simplifying
#   - Restrictions
#   - Rational equations
# - Radical expressions
#   - Simplifying radicals
#   - Radical equations
# - Nonlinear systems
#   - Linear and quadratic systems
#   - Two nonlinear equations
#   - Graphical interpretation
# - Cumulative nonlinear algebra practice
#
# #### Phase 3 — Problem-Solving and Data Analysis
# - Ratios, rates, proportions, and units
#   - Unit rate
#   - Dimensional analysis
#   - Proportional relationships
#   - Scale
#   - Rates of change
#   - Unit conversions
# - Percentages
#   - Percent of a quantity
#   - Percent change
#   - Reverse percentages
#   - Compound percentage changes
#   - Percent error
# - One-variable data
#   - Mean
#   - Median
#   - Mode
#   - Range
#   - Standard deviation
#   - Distributions
#   - Center
#   - Spread
#   - Outliers
#   - Shape of distributions
# - Two-variable data
#   - Scatterplots
#   - Positive association
#   - Negative association
#   - Strength of association
#   - Linear models
#   - Correlation vs. causation
#   - Residuals
#   - Interpreting slope
#   - Interpreting intercept
#   - Predictions
# - Probability
#   - Basic probability
#   - Compound probability
#   - Conditional probability
#   - Independent events
#   - Dependent events
# - Sampling and inference
#   - Population vs. sample
#   - Random sampling
#   - Sampling bias
#   - Margin of error
#   - Observational studies
#   - Experiments
#   - Causal claims
#   - Generalizability
# - Cumulative data analysis practice
#
# #### Phase 4 — Geometry and Trigonometry
# - Lines and angles
#   - Angle relationships
#   - Parallel lines
#   - Transversals
#   - Coordinate geometry
# - Triangles
#   - Triangle properties
#   - Similarity
#   - Congruence
#   - Pythagorean theorem
# - Right-triangle trigonometry
#   - Sine
#   - Cosine
#   - Tangent
#   - SOH-CAH-TOA
#   - Finding missing sides
#   - Finding missing angles
#   - Trigonometry in word problems
# - Area and volume
#   - Triangles
#   - Quadrilaterals
#   - Circles
#   - Cylinders
#   - Cones
#   - Spheres
#   - Composite figures
# - Circles
#   - Radius
#   - Diameter
#   - Circumference
#   - Area
#   - Arc relationships
#   - Equations of circles
# - Cumulative geometry and trigonometry practice
#
# #### SAT Data Interpretation Track
# - Reading axes
# - Identifying units
# - Interpreting individual data points
# - Identifying trends
# - Increasing vs. decreasing relationships
# - Rate of change from graphs
# - Comparing quantities
# - Tables
# - Line graphs
# - Bar graphs
# - Scatterplots
# - Experimental graphs
# - Multi-variable figures
# - Outliers and anomalies
# - Correlation
# - Causation
# - Independent variables
# - Dependent variables
# - Control groups
# - Experimental groups
# - Hypotheses
# - Evidence vs. conclusions
# - Predictions
# - Limitations
# - Interpreting scientific results
# - Integrating text with quantitative data
# - Identifying what a graph does and does not support
# - Detecting misleading graphs
#
# #### Cumulative SAT Integration
# - Mixed Algebra
# - Mixed Advanced Math
# - Mixed Data Analysis
# - Mixed Geometry and Trigonometry
# - Graph and table interpretation
# - Scientific data interpretation
# - Multi-step word problems
# - Official SAT questions
# - Timed SAT problem sets
# - Error analysis
# - Retrieval practice
# - Final cumulative practice

# %% [markdown]
# #### **Phase 0 - Mathematical Fluency**
#
# Now, this is mainly just basic arithmetic. This section is necessary for remembering building blocks, so things become more intuitive.
#
#
#
# **Fractions, decimals, and percentages:**
